# %% [markdown]
# # INDEPENDENT PROJECT

# %%
def display_menu():
    print("1. Add Task")
    print("2. Mark Task as Completed")
    print("3. List Tasks")
    print("4. Remove Task")
    print("5. Quit")

def add_task(tasks):
    task_description = input("Enter the task description: ")
    tasks.append({"description": task_description, "completed": False})
    print(f'Task "{task_description}" added.')

def mark_task_as_completed(tasks):
    list_tasks(tasks)
    try:
        task_index = int(input("Enter the task number to mark as completed: ")) - 1
        if 0 <= task_index < len(tasks):
            if not tasks[task_index]["completed"]:
                tasks[task_index]["completed"] = True
                print(f'Task "{tasks[task_index]["description"]}" marked as completed.')
            else:
                print("This task is already marked as completed.")
        else:
            print("Invalid task number.")
    except ValueError:
        print("Please enter a valid number.")

def list_tasks(tasks):
    if tasks:
        for i, task in enumerate(tasks, start=1):
            status = "Completed" if task["completed"] else "Not Completed"
            print(f'{i}. {task["description"]} - {status}')
    else:
        print("No tasks available.")

def remove_task(tasks):
    list_tasks(tasks)
    try:
        task_index = int(input("Enter the task number to remove: ")) - 1
        if 0 <= task_index < len(tasks):
            removed_task = tasks.pop(task_index)
            print(f'Task "{removed_task["description"]}" removed.')
        else:
            print("Invalid task number.")
    except ValueError:
        print("Please enter a valid number.")

def main():
    tasks = []
    while True:
        display_menu()
        choice = input("Select an option: ")
        if choice == "1":
            add_task(tasks)
        elif choice == "2":
            mark_task_as_completed(tasks)
        elif choice == "3":
            list_tasks(tasks)
        elif choice == "4":
            remove_task(tasks)
        elif choice == "5":
            print("Goodbye!")
            break
        else:
            print("Invalid choice. Please select a valid option.")
            
if __name__ == "__main__":
    main()
# Out:
# 1. Add Task
# 2. Mark Task as Completed
# 3. List Tasks
# 4. Remove Task
# 5. Quit
# Select an option: 1.
# Invalid choice. Please select a valid option.
# 1. Add Task
# 2. Mark Task as Completed
# 3. List Tasks
# 4. Remove Task
# 5. Quit
# Select an option: 1
# Enter the task description: Steps to complete coding
# Task "Steps to complete coding" added.
# 1. Add Task
# 2. Mark Task as Completed
# 3. List Tasks
# 4. Remove Task
# 5. Quit
# Select an option: Completed
# Invalid choice. Please select a valid option.
# 1. Add Task
# 2. Mark Task as Completed
# 3. List Tasks
# 4. Remove Task
# 5. Quit
# Select an option: 2
# 1. Steps to complete coding - Not Completed
# Enter the task number to mark as completed: 1
# Task "Steps to complete coding" marked as completed.
# 1. Add Task
# 2. Mark Task as Completed
# 3. List Tasks
# 4. Remove Task
# 5. Quit
# Select an option: 3
# 1. Steps to complete coding - Completed
# 1. Add Task
# 2. Mark Task as Completed
# 3. List Tasks
# 4. Remove Task
# 5. Quit
# Select an option: 4
# 1. Steps to complete coding - Completed
# Enter the task number to remove: 4
# Invalid task number.
# 1. Add Task
# 2. Mark Task as Completed
# 3. List Tasks
# 4. Remove Task
# 5. Quit
# Select an option: 4
# 1. Steps to complete coding - Completed
# Enter the task number to remove: 1
# Task "Steps to complete coding" removed.
# 1. Add Task
# 2. Mark Task as Completed
# 3. List Tasks
# 4. Remove Task
# 5. Quit
# Select an option: 5
# Goodbye!
